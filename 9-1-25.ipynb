# %%
pip install SpeechRecognition pyttsx3 pyaudio
# Out:
# ...
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
# ...

# %%
import pyttsx3
engine =pyttsx3.init()
def speak(text):
    engine.say(text)
    engine.runAndWait()

def main():
    speak("Hello! I am single bot from mallareddy university.")
    speak("You can say hello ,ask my name,or say goodbye.")
    while True:
         command = input("You: ").lower()
         if "hello" in command:
              speak("Hi there! welcome tp mallareddy university.")
         elif "what is your name" in command or "whats your name" in command:
               speak("My name id soumyareddy from mallareddy university.")
         elif "goodbye" in command:
               speak("Goodbye ! have a nice what is your name day at mallareddyuniversity")
               break
         else:
               speak("I  didn't understand that, please try again.")
if __name__ =="__main__":
    main()
# Out:
# You:  what is your name
